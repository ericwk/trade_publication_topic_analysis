# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

import json
from pymongo import MongoClient

# %%
def start_selenium_driver():
    
    '''
    Starts selenium driver in Google Chrome
    '''
    
    chromedriver = "/Applications/chromedriver"
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)
    return driver

# %%
def login_adhesives(driver):
    
    '''
    Opens Adhesives & Sealants Magazine web site log in page and submits login information.  Requires running
    start_selenium_driver() function first to provide driver
    '''
    
    driver.get('https://www.sub-forms.com/dragon/init.do?site=BNP7351_ADHESI528login&pk=RSIGN&returnurl=http%253A%252F%252Fwww.adhesivesmag.com%252Fuser%252Fpostlogin%253Fredirect%253Dhttps%253A%252F%252Fwww.adhesivesmag.com%252F')
    driver.find_element_by_id("id13").send_keys('ericwk@comcast.net')
    driver.find_element_by_id("id16").send_keys('nowme123')
    driver.find_element_by_class_name('submit').click()

# %%
def get_current_month_article_urls(current_month):
    
    '''
    Navigates to the current month issue of 'Adhesives & Sealants Industry' magazine and appends
    all article urls from each issue to a list. 
    
    Input Arguments: Current month date in format ("month_name year")
    
    Returns urls of articles in the issue.
    '''
    
    # Navigate to current issue via Selenium and collect article urls via BeautifulSoup
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.implicitly_wait(15)
    driver.find_element_by_link_text(current_month).click()
    bsObj = BeautifulSoup(driver.page_source, 'html.parser')
    urls = []
    for link in bsObj.findAll("a", href=re.compile("/articles/[1-9]")):
        urls.append(link['href'])
    
    # Remove duplicate and unwanted ("comments collection") urls
    final_urls = []
    for url in urls:
        if 'comments-container' not in url:
            final_urls.append(url)
    final_urls_set = set(final_urls)
    final_urls = list(final_urls_set)
    return final_urls

# %%
def get_articles(urls):
    
    '''
    Navigates to article url via Selenium driver, retrieves via BeautifulSoup and stores in dictionary
    article 'title', 'date', 'author' (if present, otherwise fills in "staff"), and 'text_body' into a dictionary.
    Inserts dictionary as a document into the 'articles' collection of the mongo 'adhesives' database. 
    
    Requires running start_selenium_driver(), login_adhesives() and open_mongo_database_client functions first.
    
    Requires opening mongo database client using 'adhesives' database and "articles" collection.

        client= MongoClient()
        db = client.adhesives
        articles_collection = db.articles
    
    Input Arguments:  A list of urls.  Can be output of get_current_month_article_urls or
    get_archived_article_urls functions
    '''
    
    for url in urls:
        # Navigate to url via Selenium (after login) and open page in BeautifulSoup
        driver.get(url)
        bsObj = BeautifulSoup(driver.page_source, 'html.parser')
        
        # Retrieve title, date, author and text body from article and insert into dictionary.
        article = {}
        try:
            article['title'] = bsObj.find('h1').text
        except(AttributeError):
            article['title'] = -9
            print("No title found for:", url)
        try:
            article['date'] = bsObj.find(class_='date').text
        except(AttributeError):
            article['date'] = -9
            print("No date found for:", url)
        try:
            article['author'] = bsObj.find(class_='author').find('a').text
        except(AttributeError):
            article['author'] = 'staff'
        try:
            output = ''
            for x in bsObj.find(class_='body gsd-paywall').find_all('p'):
                output += x.text + ' '
            article['text_body'] = output
        except:
            article['text_body'] = -9
            print("No text body found for:", url)
    
        # Insert dictionary as a record into articles table in the adhesives Mongo database.
        articles_collection.insert_one(article)
        
        print(article['title'])

# %%
driver = start_selenium_driver()

# %%
login_adhesives(driver)

# %%
current_urls = get_current_month_article_urls('August 2018')

# %%
client= MongoClient()
db = client.adhesives
articles_collection = db.articles

# %%
articles_collection.delete_many({})
get_articles(current_urls)
# Out:
# Applying Rapid-Cure Adhesives with a Meter/Mix/Dispense System
# Industry Leaders to Gather at ASC Executive Leadership Conference
# Evaluating Adhesive Options in Packaging Applications
# 3M Sales Rise 7% in Second Quarter 2018
# Sika Automotive Receives Product Leadership Award
# Evonik Reorganizes Distribution Structure
# Ranking the Leading Adhesives and Sealants Manufacturers in the ASI Top 25
# Liquid Polysulfide Polymers for Chemical- and Solvent-Resistant Sealants
# 2018 ASI Top 25:  Leading Global Manufacturers of Adhesives and Sealants
# Afera First Global Adhesive Tape Summit  a Success
# Pilot Chemical Opens Innovation Center

# %%
def get_archived_article_urls(current_month, oldest_issue):
    
    '''
    Navigates to the current month issue of Adhesives & Sealants Magazine following login via
    login_adhesives() function.  Navigates to past month drop down list (archived issues),
    loops through past month issues and appends all article urls from each issue to a list.  Deletes
    duplicate urls and urls for 'comments-container' for each article urls.
    
    Input Arguments: 
    'current_month' - Current month date in format ("month name year")
    'oldest_issue' - Number of issue months past at which to stop
    
    Returns list of article urls
    ''' 
    
    # Navigate to current issue via Selenium and collect article urls via BeautifulSoup
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.implicitly_wait(30)
    # Open drop down list to select archived issue
    driver.find_element_by_link_text(current_month).click()
    driver.implicitly_wait(10)
    
    # Loop through archived issues appending article urls to list
    urls = []
    for issue in range(1, oldest_issue):
        driver.find_element_by_xpath('//div[@class="selectize-control single"]').click()
        driver.implicitly_wait(10)
        path = '//div[@class="selectize-dropdown-content"]/div[{}]'.format(issue)
        driver.find_element_by_xpath(path).click()
    
        bsObj = BeautifulSoup(driver.page_source, 'html.parser')
    
        for link in bsObj.findAll("a", href=re.compile("/articles/[1-9]")):
            urls.append(link['href'])
    
    # Remove duplicate and unwanted ("comments collection") urls
    final_urls = []
    for url in urls:
        if 'comments-container' not in url:
            final_urls.append(url)
    final_urls_set = set(final_urls)
    final_urls = list(final_urls_set)
    return final_urls

# %%
driver = start_selenium_driver()

# %%
login_adhesives(driver)

# %%
archived_urls = get_archived_article_urls('August 2018', 61)

# %%
get_articles(archived_urls)
# Out:
# 3M Sales Rise 7% in Second Quarter 2018
# UV-Curable Ink Applications Increase
# Advancing Adhesives: A New Wave of Waterborne Dispersions for Adhesives and Coatings
# A Natural Choice for Adhesives and Sealants
# Mergers and Acquisitions in Adhesives and Sealants: 2015-2016 Review and Forecast
# Strategic Solutions: Championing Executive Leadership in Internet Marketing
# Vienna to Host 2016 FEICA Conference
# Nashville Hosts the Adhesive and Sealant Council Spring 2015 Convention and Expo
# North America Dominates Oilfield Biocides Market
# Ask Dr. Dave: Should we consider silicones or polyurethanes for our construction applications?
# Case Study: Managing Energy Use in Manufacturing
# FEICA 2017 Will Focus on Innovation
# Ask Dr. Dave
# Editor’s Memo: And the Winners Are…
# Planning Ahead for Adhesive and Sealant Success
# Ask Dr. Dave: October 2013
# 2015 Adhesives and Sealants Raw Materials and Chemicals Roundtable
# Boosting ROI with Powerful PR and Social Media
# Converting Equipment for Pressure-Sensitive Adhesives
# Advancing Adhesives: A Natural Feedstock
# Case Study: Foam Tape Helps Specialty Appliances Provider Seal the Deal
# Beyond Adhesion: Disruptive Innovation’s Impact in Transportation Adhesives
# Top 50 ASI News Stories of 2014
# Pittsburgh Hosts Adhesive and Sealant Council Fall 2015 Convention and Expo
# Repackaging Options for Two-Component Adhesives, Sealants and Coatings
# State of the U.S. Construction and Remodeling Markets
# Editor's Memo: Are We Slaves to Electronics?
# Packaging a Solution for an Electronics Manufacturer
# Tape Summit 2016 in the Sunshine State
# Product Disclosure: Opportunities and Challenges for the Adhesives and Sealants Industry
# Editor's Memo: Innovation Abounds
# 4 Trends Impacting the Global Adhesives and Sealants Industry
# Understanding the Role of Fumed Silica in Adhesives and Sealants Formulations
# Novel Technology for Non-Silicone, Non-Solvent-Based Release Coatings
# IP in Depth: Expediting Patent Application Examinations
# Managing Inventory: A Delicate Balance
# Top 5 Trends in Enterprise Labeling for 2016
# Market Trends: Coatings Industry Continues to Evolve
# Regulatory Review: Adhesives Manufacturers Blindsided from the Left Coast
# Case Study: A Thermoplastics Compound Manufacturer is Going to the Next Level
# It’s The Assembly Show Time!
# Painting the Future of Education in Utah
# Materials Roundtable: Let's Talk Materials
# Baltimore Hosts the Pressure Sensitive Tape Council's 2015 Tape Summit
# Editor's Memo: The "People" Business
# What alternatives do I have for bonding to surfaces like polyethylene and polypropylene?
# Environmental Coatings Consumption Continues to Rise
# Yee-Haw: Adhesives and Sealants Industry Heads to Nashville!
# Material Solutions for Medical Wearables
# Advancing Adhesives: Reusable and Renewable Adhesive Mimics Geckos
# Top 10 ASI New Product Stories of 2015
# Top 5 Adhesives and Sealants Market Reports of 2016
# Certifying Sealant Flow Behavior and Tackiness
# Breaking Packaging Barriers with Oxygen Barrier Coatings
# Double-Down on Case Sealing Success
# Adhesives at Work: Vacuum Dispensing of Ignition Coils - Sophisticated Technology Made Affordable
# A New Cure for Adhesives and Sealants
# Case Study: Conveying a New Hot-Melt Adhesive Solution
# Customizing Efficiency in Manufacturing
# Ranking the Leading Adhesives and Sealants Manufacturers in the ASI Top 25
# Lignin in the Laboratory
# Making Adhesives and Sealants Safer
# Perfecting Dosage in Medical Applications
# "Boring" Boron and Adhesives
# Silicone Technology for Aerospace and Aircraft
# Foam Expo North America Show Wrapup
# Focus on the Future of the Adhesives and Sealants Industry
# Advancing Adhesives: New Coating is a Bacteria Barrier
# Underwater Bonding
# Indy to Host Adhesive and Sealant Council Fall Convention and Expo
# Improved Rheological Quality Control Tests for Today's Adhesives and Sealants
# Next-Generation Acrylic Adhesives Enhance Assembly Operations
# Regulatory Review: New SDSs and Labels for GHS Compliance - Don't Panic Yet
# Adhesives at Work: Innovative Label Adhesives Meet Today's Packaging Demands
# Regulatory Review: Holistic Environmental Regulation
# Adhesives Consumption Growing Despite Environmental Restrictions
# Top 25 ASI Feature Articles of 2016
# All Adhesive and Sealant Meter/Mix Systems Are Not Created Equal
# Q&A About Polyurethanes: Prepolymers with Low Isocyanate Content
# Market Trends: Silicone Sales Continue to Rise
# Top 10 ASI News Stories of 2017
# Case Study: PPG Aerospace Coatings Add Character to Cathay Pacific Jet
# Focus On: H.B. Fuller Grows through Acquisitions
# Market Trends: Medical Device Coatings on the Rise
# Regulatory Review: TSCA Reform - The Time is Now
# UV/Vis Energy-Cure Adhesives and Sealants: Industry Trends, Chemistry, and Packaging
# The Future Is in Sustainability and Safety
# What types of chemical structures could be built into a polyurethane adhesive to optimize heat resistance?
# Assembly Show Returns to Rosemont: Opportunities for Adhesives and Sealants
# Focus On: Bostik Celebrates 125 Years of Innovation
# Advancing Adhesives: Bio-Based Polyols for High-Performance Polyurethane Adhesives
# Editor's Memo: Happy New Year!
# Customized Coatings for an Outdoor Structural Application
# Innovations in Release Liners
# Editor's Memo: 2014 ASI Top 25
# CE Marking Compliance: Risks and Rewards for Sealant Manufacturers
# Rise of Wireless Technology Poses Security Risks for Manufacturers
# Dibenzoate Plasticizers in Waterborne Acrylic PSAs
# Four Ways to Improve Communication at Work
# Building Industry Knowledge: Preview of the ASC Fall Convention and Expo
# IP in Depth: Effective Preissuance Submissions
# What types of surface preparation are necessary to obtain strong and durable bonds?
# Raw Materials, Chemicals, Polymers and Additives
# Determining the Volatile Content of Coatings
# Market Trends: Lightweighting is Strengthening the Global Automotive Adhesives and Sealants Market
# 3-D Vision Enables Challenging Adhesive Inspection Applications
# What is the difference between a hardener, a primer, an accelerator, and an activator?
# Editor's Memo: Dispensing and Curing and More!
# Radiation-Curable Pressure-Sensitive Adhesives
# Previewing the American Coatings Show and Conference
# How to Use the Buyers' Guide
# Going Solar
# What technologies are involved in making adhesives that fluoresce under ultraviolet (UV) light?
# Top 10 ASI Market Trends Stories of 2015
# Evolving Pressure-Sensitive Tape Adhesives
# Editor’s Memo: Continual Evolution
# Pressure-Sensitive Adhesives Are in the Driver's Seat
# Strategic Solutions: LEED v4: Do Contractors Understand Adhesives Product Information?
# Assembling Our World
# Market Trends: Adhesive Films Market to See Solid Growth
# Join Us in Atlanta for the Adhesive and Sealant Council’s Annual Spring Convention and Expo
# Editor's Memo: Managing Expectations
# Advancing Adhesives: Prefab Houses are Taped - Not Nailed - Together
# Photovoltaic Module Rail Bonding with Acrylic Foam Tapes
# We want to bond steel to foamed polystyrene. What do you recommend?
# Focus On: Chemicals Supplier Celebrates an Interactive Anniversary
# Advancing Adhesives: Non-Toxic Solvents
# ASSEMBLY Show Returns to Rosemont: Opportunities for Adhesives and Sealants
# Editor's Memo: 2015 ASI Readers’ Choice Winner Announced!
# Logistics and Shipping Drive Gummed Tapes Growth
# Travel Is in the Air
# Strategic Solutions: Commodity Selling in the Adhesives and Sealants Industry
# Advancing Adhesives: ExxonMobil Announces Major Tackifier Expansion
# ECS Returns to Nuremberg
# Q&A About Polyurethanes
# Ask Dr. Dave: What are the best adhesives and sealants for construction these days?
# Pressure-Sensitive Tapes to See Strong Demand
# Plan Now to Profit from Sustainability
# Tokyo to Welcome World Adhesive and Sealant Conference
# Optimizing Adhesives for Tankless Dispensing Systems
# Winning in a Dynamic and Inclusive Market
# Making Safety Stick Can Save More than Millions for Adhesives and Sealants Manufacturers
# The two-component epoxy we're usinng in a metal assembly operation on small parts doesn't cure fast enough. Can you help?
# Market Trends: Global Consumption of Radiation-Cured Products
# Employers Should Brace for a Big Impact from New OSHA Rules
# Strategic Solutions: Surface Treatment - A Formulator's Friend for Adhesives, Sealants and Coatings
# Can you recommend a safe adhesive for bonding plastics?
# Advancing Adhesives: Bio-Based Succinic Acid Polyester Polyols
# Editor's Memo: Taking Things Easy?
# Las Vegas Hosts PSTC Tape Summit
# Solid Reasons for Solid Systems
# Improving Operations with ERP
# Understanding the Value of Your Business
# Should I use a cyanoacrylate superglue for household repairs and assembly projects?
# Market Trends: "Smart" Packaging on the Rise
# Rotary Batch Mixer Blends Wood Powders for Plywood Adhesives
# Adhesive and Sealant Council Announces Fall Convention Keynote Speakers
# Adhesives at Work: U.S. Coast Guard Turns to Electrocoat Primer System
# Regulatory Review: Into the West
# Top 30 ASI Feature Articles of 2015
# Auto, Packaging, Construction Lead Adhesives and Sealants Market Growth
# Automation in the Metering, Mixing and Dispensing of Adhesives and Sealants
# Transparency through an Agency Website? Maybe Not.
# 2016 Raw Materials and Chemicals Roundtable
# We’ve been trying to get the metal button of a rear-view mirror to bond to a new windshield.
# Sustainable Safety
# Failure-Free Gluing for Custom Boxes
# Finding the Oz in the Adhesives and Sealants Industry
# Market Trends: Multiple Factors Driving Growth for Electronics Adhesives
# A Sealant Solution
# Top 5 ASI New Product Stories of 2013
# A Static Solution for Manufacturers of Adhesives and Sealants
# Case Study: Polyurethane Sealants Lead to Energy Savings
# The TSCA Miracle of 2015
# Serve to Be Great: 11 Leadership Lessons from a Prison, a Monastery and a Boardroom
# Market Trends: Automotive Industry Keeps Thermoplastic Elastomers Market Strong
# Ask Dr. Dave: What's a safe adhesive for bonding plastics?
# Editor's Memo: On the Move
# Find Your Distributor
# Editor's Memo: The Green Stuff
# Selecting the Optimal Adhesive for Wearable Medical Devices
# Q&A About Polyurethanes: September 2013
# Strategic Solutions: Adhesives and Sealants Market Overview and Outlook
# Ask Dr. Dave: How can I tell if my adhesive has fully cured?
# Spray-on Coating Solution Makes Ice Slide Off
# Pre-Dispersion Equipment Engineered for Lightweight Adhesive Fillers
# Adhesive labels for packaging face increased regulations in California
# Spider Silk Brings Adhesive Opportunities
# Bio-Based Feedstocks for Adhesives and Sealants: Everything Old is New Again
# Advancing Adhesives: Hot-Melt Adhesives are Packed to Perfection
# Improving Performance of Hot-Melt Packaging Adhesives
# Innovation and the Future of Liquid Filling Machines for Adhesives and Sealants
# Polyaspartic Coatings
# Market Trends: Sealant Demand Growing in Europe
# Adhesive and Sealant Market Overview and Outlook
# Innovations in Curing Adhesives and Sealants
# 2018 Raw Materials, Chemicals, Polymers and Additives Handbook
# Mixing and Dispersing Silicones
# Case Study: Living Under the Same Roof
# Dispensing Systems for Dosing Two-Component Silicones
# Flame-Retardant Foam Gaskets: Fire Proof and High Performing
# Preview of the ASC Fall Convention and Expo
# Market Trends: Global Automotive Composites Market on the Rise
# Ask Dr. Dave: What adhesives do you recommend for bonding fiberglass for indoor applications?
# Spray Polyurethane Foam Application: When Are Workers Safe?
# Silane and Catalyst Effects on Silylated Polymer Elastomers
# High-Performance Bonding
# Ask Dr. Dave: Please explain tack, peel adhesion and shear strength in regards to pressure-sensitive adhesives.
# Ask Dr. Dave: December 2013
# Sustainability Drives Coatings Consumption
# Case Study: Material and Product Intelligence for the Adhesives and Sealants Industry
# Two-Part Adhesives and Application Equipment
# Top 15 ASI Market Trends Stories of 2014
# Why use pressure-sensitive tape adhesives in the assembly of electronic devices?
# Editor's Memo: Adhesives and Sealants Contribute to Mind-Blowing Progress
# Silo Systems for Safety
# Industry Gathers in Tokyo for World Adhesive and Sealant Conference
# Regulatory Review: TSCA Reform - Can the Senate Get There in 2014?
# Editor's Memo: Potpourri
# Electron Beam Technology for Pressure-Sensitive Adhesive Applications
# A Holistic Approach to Adhesive Selection
# Case Study: Customizable Keypads Feature Decorative Adhesive Skins
# Concrete Coatings: Polyurethane, Polyurea and Multi-Coat Systems
# Ask Dr. Dave: September 2013
# Enabling High-Tech Innovation with Electronic Adhesives
# Mergers and Acquisitions in the Adhesives and Sealants Industry
# Three Marketing Technologies B2B Companies Can No Longer Ignore
# 2016 Raw Materials and Chemicals Overview
# Dispensing & Curing
# Maximizing Quality and Cost Benefits with Structural Adhesive Testing
# Vehicle Ownership Rates Driving Auto Refinish Coating Market
# TSCA Could Provide Unintended Consequences
# Carbon Fiber: Strong Bonds, Strong Growth
# Sticking with Science
# Pressure-Sensitive Adhesive Characteristics and their Impact on Foam Anchorage
# Achieving Adhesion to Difficult Substrates
# Applying Rapid-Cure Adhesives with a Meter/Mix/Dispense System
# Case Study: A Standardized Bonding and Application Solution
# Hydroxyl-Terminated Polybutadiene Liquid Resins for Adhesives Applications
# Eliminating Common Metering and Dispensing Problems
# Curing Adhesives: When Less Intensity Is More
# Market Trends: Bioadhesives Fill the Gaps
# Touchscreen Manufacturing with UV LED Curing Technology
# Ask Dr. Dave: Should we be concerned about shrinkage of our adhesives on curing?
# Q&A About Polyurethanes: Increasing  Market Requests for Sustainable Adhesives
# Using Multi-Zone Irradiance Control in UV LED Systems
# Selecting UV Spot-Curing Technology
# Retaining Reliability and Endurance in Punishing Applications
# Introduction to Farnesene-Based Polyols for Adhesives and Sealants Formulation
# Ask Dr. Dave: How can we get our adhesives approved for food/beverage or medical applications?
# Disposable Static Mixers: A Maturing Industry
# Is handling one-component polyurethane adhesives and silicone sealants difficult?
# Case Study: Adhesive Promotes Unbreakable Displays in Automotive Applications
# Making Automotive Sealers Behave
# Case Study: Air-Operated Double-Diaphragm Pumps Provide the Glue of the Operation for an Adhesives Manufacturer
# Ensuring Floor Covering Sustainability
# 6 Key Trending Topics for the Adhesives and Sealants Industry
# Editor's Memo: Focusing on Innovation
# Release Liners: Clay-Coated Kraft vs. Polyethylene-Coated Papers
# Top 10 ASI New Product Stories of 2014
# 2016 ASI Top 25: Leading Worldwide Manufacturers of Adhesives and Sealants
# Afera First Global Adhesive Tape Summit  a Success
# Sustainable Raw Materials: How to Plan for Market Success
# Replicating History with Structural Adhesives
# What options do we have for high-performance liquid gaskets?
# Correlating Substrate Surface Analysis to Adhesive Performance
# Topcoat Coating System Helps Flying Colours to Soar
# Two-Component Dispensing Solution for Adhesives and Sealants
# Coatings, Adhesives, Sealants and Inks Continue to Grow
# Label Demand Rolls Ahead
# Can we speed up curing of an UV adhesive/sealant by using a full-spectrum bulb from the hardware store?
# Ask Dr. Dave: Why are some waterborne adhesives called latex, others called dispersions and yet others emulsions?
# U.S. Demand for Natural Polymers to Exceed $5 Billion
# Modular and Flexible Automated Pail Processing
# Evaluating Adhesive Options in Packaging Applications
# Adding Functionality to Hot-Melt Adhesives
# 2015 ASI Readers' Choice Award Winners
# Focus On: Adhesives and Coatings Manufacturer Undergoes an Environmental Upgrade
# What type of raw materials should be considered in formulating products with a bio-based focus?
# Ask Dr. Dave: We noticed that there are a lot of brown particle in the dispenser we use for hot-melt adhesives. What is it?
# How Can Structural Adhesives Help Automakers Tackle a Weighty Issue?
# Plasticizer Migration: Ensuring Safety in Food Packaging
# Pilot Chemical Opens Innovation Center
# Recent Advances in Die-Attach Film Adhesives
# Nashville Welcomes the Pressure Sensitive Tape Council's Tape Summit 2014
# 2013 ASI Readers' Choice Awards
# Adhesives at Work: Using Conductive Adhesives for Thermal Management in Micro- and Power Electronics
# 2018 ASC Convention and Expo Exhibitors List
# Our Annual Equipment Handbook Provides Sourcing Information for Equipment
# Case Study: Ammunition Sealant Dispensing System
# Styrenic Block Copolymers for Hot-Melt Pressure-Sensitive Label Adhesives
# Transforming the World through Technology
# Ask Dr. Dave: What is the best way to prepare aluminum surfaces for bonding with epoxy or acrylic adhesives?
# Focus On: Henkel is Connecting to Success
# Strategic Solutions: Construction, Crude Oil, and Natural Gas Outlook
# Nasal Strip Adhesion
# Focus On: One Supplier to the Adhesives and Sealants Industry is Finding Diamonds in the Rough
# Advancements in UV LED Curing Technology for Adhesives
# Distributor Roundtable: Exploring the Relationship Between Distributors and Adhesives and Sealants Manufacturers
# Ask Dr. Dave: What are the best products for filling the seams after assembling acrylic countertops?
# Environmentally Sound Pressure-Sensitive Adhesive Tape Manufacturing
# Marketing and the Myth of “A New Idea”
# Surface Treatment Effects
# Assembly in Action
# Market Trends: Worldwide Composites Markets Growing
# Taking the Lead of the Adhesives and Sealants Industry
# Clean and Green PSAs
# Hot Melts: A Dynamic, Growing Market
# A Fast Guide to Fast-Curing Floors
# Increasing Production Marketing, Uptime and Throughput in Packaging Applications
# Market Trends: Construction Chemicals Market is Building on Success
# Advancing Adhesives: Advancing Medical Labels
# Continued Growth for Adhesives in Electronics
# Raw Materials, Chemicals, Polymers and Additives Handbook Issue
# Construction Growth Driving Adhesive and Sealant Demand
# Formation and Determination of Aldehydes in Amine Catalysts
# Pressure-Sensitive Adhesives Market  to Cross $11 Billion by 2024
# Using Rheology to Formulate Sealants
# The Next Big Thing in Coatings is Very Small
# Handle with Care: Personnel Protection in the Adhesives and Sealants Industry
# A Safer Alternative Takes the Pressure out of Formulating Pressure-Sensitive Adhesives
# Focus On: 50 Years of Coatings Success
# Linking New Product Strategy and Tactics with Forecasts
# 5 Trends Impacting the Adhesive and Sealant Industry
# Collaborating for Success in the Adhesives and Sealants Industry
# Case Study: Runway Reconstruction
# Novel Amorphous Polyolefins for Adhesive Applications
# Understanding Solvent Acrylic Pressure-Sensitive Adhesive Systems
# Advancing Adhesives: Magnetic Pollen Replicas are a Sticky Business
# UN-Rated Steel Pails for the Packaging of Adhesives and Sealants
# Case Study: Enhancing Efficiency in Adhesives and Coatings Manufacturing
# On the Bonding Edge
# Keeping Canada Dry with Waterproof Sealants
# Welcome to 2017!
# Soft Silicone Adhesives Crucial for Atraumatic Advanced Wound Care Dressings
# Nanomaterials in the Workplace
# Market Trends: China Leads Adhesives Growth
# State of the U.S. Construction Market
# Tapes Deliver a Sticky Situation to Reality Television Show Contestants
# Turbocharging Innovation in Adhesives and Sealants
# Common Problems with Common Tests
# 2017 Raw Materials and Chemicals Roundtable
# Sourcing Equipment
# Focus On: Industrial Packaging Goes Green
# Case Study: Keeping Odor and Flames at Bay with VAE Dispersions
# Previewing the Adhesive and Sealant Council's Spring Convention and Expo
# American Coatings Show Comes to Indy
# Editor's Memo: New Year, New Look for Adhesives & Sealants Industry
# Editor's Memo: Let's Talk Materials
# Sustainable Success for Adhesives and Sealants through Biorenewable Feedstocks
# Ask Dr. Dave: What is the difference between a polyurethane adhesive and a polyurea adhesive?
# A Closer Look at Planetary Mixers for Adhesives and Sealants Production
# Handicapping the Field: How Next-Generation Solar PV Materials Will Emerge into the Market
# Accelerating 3D Printing for Industrial Manufacturing
# Innovation in Flooring Adhesives
# Adhesives at Work: Stay Ahead of the Pack - Sticking to Food Packaging Regulations
# Case Study: Structural Adhesives Increase Productivity for Electric Vehicle Assembly
# The Future of Electron Beam Curing
# Beyond Adhesion
# Distributor Directory
# 2015 Materials and Chemicals Overview
# Meeting Expectations
# Better Health at Bargain Prices: Six Ways to Institute an Affordable Workplace Wellness Program
# Up for Discussion: Bidding Exercises Spell Bad News for Adhesives and Sealants Industry
# Top 5 ASI Market Trend Stories of 2013
# Q&A About Polyurethanes: Raw Materials Storage Issues
# Focus On: New Technology Enables Self-Adhesive Media to be Removed Without a Trace
# Adhesives at Work: Filters Reduce False Sealant Failures
# Improving Assembly with Fastener and Component Enhancement Materials
# 2018 Raw Materials and Chemicals Roundtable
# Adhesive and Sealant Council Convention and Expo Comes to Atlanta
# What is the best way to store my epoxy and acrylic adhesives?
# Sika Automotive Receives Product Leadership Award
# Top 10 ASI New Product Stories of 2016
# Strategic Solutions: State of the U.S. Adhesives and Sealants Industry
# New Automotive Refinish Drives Change
# Reshaping Adhesive and Sealant Formulation Strategies
# Market Trends: China Is a Hot-Melt Adhesives Hot Spot
# Focus On: Adhesive Mixing Technology Can Help Facilitate Sustainability in Dental Practices
# Comparing UV Acrylate Performance in Laminating Adhesives for Durable Electronics Applications
# The Assembly Show is Back!
# IP in Depth: Avoiding Unnecessary Disclosures in Patent Applications
# Ask Dr. Dave: Can I dispose of water that has adhesive residue?
# Understanding OSHA's Revised Hazard Communication Standard
# Bio-Coatings Improve Implant Functionality
# Case Study: ERP System Helps Chemical Distributor Boost Productivity
# Innovation in the Adhesives and Sealants Industry
# Viscosity Analysis: Flow Curve, Yield Stress and Creep
# How to Use the Buyers' Guide
# IP in Depth: Compact Prosecution
# Top 10 ASI New Product Stories of 2017
# Q&A About Polyurethanes: Formulating Basics for Coatings
# Is Your Company the Next Blockbuster?
# Ask Dr. Dave: How can we ensure that our acrylic emulsion adhesive testing results will be predictive of the stability of all package sizes?
# Editor's Memo: ASI Top 25
# In Pursuit of Operational Excellence
# Raw Materials and More
# Nondestructive Inspection for Heat Sink Efficiency
# Convertible Flexible Packaging Demand Increases
# Sustainability
# Advancing Adhesives: Finding Adhesive Solutions
# Market Trends: The "Case" for the U.S. CASE Market: 2015-2016
# Editor's Memo: Material Matters
# Lots to See and Do at the ASC Annual Spring Convention and Expo
# Top 10 ASI News Stories of 2016
# Strategic Solutions: Tips for Successful Adhesives and Sealants Business Development
# How do I disassemble nuts and bolts that were assembled using anaerobic threadlockers, then re-use the fasteners?
# Window Film and Affordable Sustainability
# Multiple Factors Contribute to Increasing Global Demand for Pressure-Sensitive Adhesives
# Focus On: Threadlockers Lock it Down
# Polyurethane Laminating Adhesives for Hard-to-Bond Substrates
# Adhesive and Sealant Council 2014 Fall Convention and Expo
# From the ASC President: Gather with the Adhesives and Sealants Industry in Miami
# Using Structural Adhesives in Car and Truck Accessories Manufacturing
# Top 30 ASI Feature Articles of 2014
# Transposable Adhesives: Acrylic Pressure-Sensitive Adhesives with Reactive Components
# The Greener Side of Adhesive Coating
# FAQs about Pressure-Sensitive Adhesives (PSAs)
# Market Trends: China’s Silicone Sealant Market
# How do I select the right adhesive or sealant to bond and seal industrial components?
# Ask Dr. Dave: Is there a way to bond PTFE with regular adhesives?
# Food Safety in Flexible Packaging Adhesives
# Flexible Plastic Packaging Market to Grow 5%
# Ask Dr. Dave: What is a good adhesive for bonding glass to metal?
# What tips can you provide for bonding plastics and composites with adhesives?
# Top 25 ASI News Stories of 2015
# Sexual Harassment: What’s Happening?
# Focus on Raw Materials, Chemicals, Polymers and Additives
# Wilden Celebrates 60 Years
# Solutions in Silicone
# Mechanical vs. Adhesive Bonds in Assembly
# Packaging Matters
# Adhesives and Sealants' Role in Electronics Device Design
# Formulating Energy-Curable Laminating Adhesives
# Regulatory Review: South Coast Overhaul of Rule 1168 Will Alter VOC Limits
# Strategic Solutions: The Future of Adhesives and Sealants
# 2017 ASI Top 25: Leading Worldwide Manufacturers of Adhesives and Sealants
# Emerging Hot-Melt Technologies for Package and Container Sealing
# I am trying to understand how the organosilanes act chemically.
# Top 50 ASI News Stories of 2013
# Replicating History with Adhesives
# How to Use the Adhesives & Sealants Industry 2015 Buyers' Guide
# Ask Dr. Dave: What is the best way to judge the effectiveness of an adhesive bond?
# Flexible Formulation of Waterborne Caulks and Sealants
# 2018 ASC Convention and Expo Attendees Can Benefit from Multiple Networking Opportunities
# New Orleans Hosts Adhesive and Sealant Council Spring 2016 Convention and Expo
# 2015 ASI Top 25: Leading Worldwide Manufacturers of Adhesives and Sealants
# ASI Top 25 Rankling of Adhesives and Sealants Manufacturers
# Q&A About Polyurethanes: Coatings Raw Materials
# Delivering Value with Adhesives and Sealants
# Solving Engineering Challenges with Functional Coatings
# Is there a PSA that can be removed and reapplied a number of times without losing adhesion?
# Editor's Memo: Distributor Directory
# Case Study: A Speedy Solution for Glue Extender Production
# Staying Ahead of the Curve
# Construction Adhesives and Sealants Manufacturer Celebrates a Milestone
# Thinking Green: Sustainable Adhesive and Sealant Packaging Options
# Mixing Two-Component Fluids in Exacting Proportions
# Ain't No City Like New Orleans for Spring ASC Convention
# Ask Dr. Dave: What type of adhesive should we use to replace mechanical fasteners for metal assembly?
# Editor's Memo: New Year's Resolutions
# Evolving Distribution Services for the Adhesives and Sealants Industry
# Developing Pressure-Sensitive Adhesives for Low-Temperature Applications
# Strategic Solutions: Selling Green
# Focus On: Adhesive Suppliers and Manufacturers Make Strides in Serving the Packaging Sector
# Ask Dr. Dave: How should I choose between an acrylic adhesive and an epoxy?
# Aerospace Sealant: A Positive Partnership
# 2017 Materials and Chemicals Overview
# Rubber-Based Hot-Melt Pressure-Sensitive Adhesives
# Surging Demand Driving Nonwovens Growth
# Going Green in the Adhesives and Sealants Industry
# Integrating Adhesives with Assembly
# Focus On: Bostik Takes its Brand to the Skies
# Editor's Memo: How to Use the Buyers' Guide
# I use epoxy sticks; are silicone adhesives and sealants in a similar form available?
# The Future is Now
# Q&A with Pine Chemicals Association International President Sherry Keramidas
# Carbon Dioxide-Based Polycarbonate Polyols for Polyurethane Systems
# High-Accuracy Filling Equipment and Automation Improves Production Operations
# How to Sustain Regulatory Compliance for Chemical Labeling
# Improving the Quality and Efficiency of Adhesives in the Glass Industry
# Understanding How Tape Works
# Talking Adhesive and Sealants Tapes
# Differential Release Liners Defined
# Integrating a Full-Service Converter into Your Supply Chain
# How should we prepare our surfaces for adhesive bonding?
# Char in Hot-Melt Adhesives: Eliminating the Enemy
# Shale Gas Impact on Tackifier Feedstocks
# How do we get rid of the mess created from using fumed silica?
# Vacuum Dispensing Helps Users Say Goodbye to Air Bubbles
# Do reactive acrylics and anaerobics behave like epoxies in terms of curing?
# Is a Failed Product a Failure – Or Opportunity?
# Ask Dr. Dave: How can we ensure that UV-curable adhesives are always fully cured?
# Advancing Adhesives: Improving Hot-Melt Adhesives
# Medical Market to Spur U.S. Silicone Demand
# Market Trends: Solvents Market on the Rise
# Rapid Adhesive Bonding by Induction and Microwave Curing
# What has been your experience using silicone caulks, both interior and exterior?
# Have there been any new adhesives for consumer or handyman use recently?
# Focus On: Sailing on Solar with Structural Adhesives
# Guest Editorial: ASC: Securing Our Future
# Promoting Sustainability with FIBCs
# Market Trends: Lightening Up with Carbon Fiber-Reinforced Plastics
# Liquid Polysulfide Polymers for Chemical- and Solvent-Resistant Sealants
# 2018 ASI Top 25:  Leading Global Manufacturers of Adhesives and Sealants
# Enhancing Assembly Line Efficiencies with Silicone Foams
# Minding the Gap Between Adhesives and Sealants Manufacturers and End Users
# UV LED Curing Technology
# 2014 ASI Top 25: Leading Worldwide Adhesives and Sealants Manufacturers
# ASI Top 25
# Ask Dr. Dave: November 2013
# Creating Flow in High-Variety Environments
# Eco-Friendly Adhesives for Converting and Packaging
# I see a lot of job advertisements for polyurethane chemists. Why the sudden interest?
# Case Study: Advancing Automobiles with Adhesives
# An Electronics Evolution
# Which hardeners are recommended for very fast curing epoxy adhesives?
# PSTC Tape Summit Honors Past, Looks to Future
# Pressure-Sensitive Medical Technology: Challenges and Considerations
# Is it Time to Upgrade Your Mixer?
# Lighter, Safer and Stronger
# Strategic Solutions: A New Decision-Making Framework
# Nonwovens Disposable Hygiene: A World of Opportunity for Adhesive Manufacturers and Dispensing Equipment Suppliers
# Next-Generation Vertical Double Planetary Kneaders Mix It Up
# Hot-Melt Adhesives 101: A Primer for Users
# Ask Dr. Dave: Could you please give us an overview of polyurethane adhesives?
# Evonik Reorganizes Distribution Structure
# Using Bio-Waste and Other Alternatives as Green Adhesives
# Travel Season is Approaching, and We're Looking Forward to the American Coatings Show and Conference and the ASC Annual Spring Convention and Expo
# The Future of Pressure-Sensitive Graphic Films
# Portugal to Welcome 2015 FEICA Conference
# Top 20 ASI Feature Articles of 2013
# Solving Complex Adhesion Problems with Plasma
# Top 9 Adhesives and Sealants Market Reports of 2017
# 2015 Adhesives and Sealants Industry Distributor Roundtable
# Cultivating Distributor Relationships in the Adhesives and Sealants Industry
# Editor's Memo: ASC Fall 2013
# Industry Leaders to Gather at ASC Executive Leadership Conference
# Aligning Adhesive Price and Performance
# Ask Dr. Dave: Is it serious for end users if there are some lumps in a construction adhesive paste?
# Editor's Memo: How to Use the Buyers' Guide
# Strategic Solutions: State-of-the-Industry Report
# Improving Polyurethane Coatings for Water Infrastructure
# Service with a Smile?
# Case Study: Product Switch Eliminates Tape Lifting Concerns
# Adhesives at Work: Stuck on Heat Sinks
# A Structural Adhesive Transforms the Hovercraft Assembly Process
# Top 14 ASI Feature Articles of 2017
# Advancing Adhesives: Formulating Sealants that Retain Adhesion to Concrete in Wet Conditions
# Selecting Adhesives: Converting Every Opportunity into Success
# Customized Structural Adhesives Deliver Multiple Benefits
# Editor's Memo: Distributor Partners for the Adhesives and Sealants Industry
# Successful Converting with Pressure Sensitive Adhesives
# Why Smart Manufacturing is a Dumb Idea
# Can you comment on the stresses created by structural adhesive bonding?
# Market Trends: Growth Continues for Asia-Pacific Coatings Market
# Supply Chain Operating Networks Accelerate Profitable Growth
# The Right Packaging for Finished Adhesives
# Unmet Needs in Adhesives Technology for OEM Transportation Applications
# The Next Generation
# Coatings Industry Gathers in Germany
# Latvia Hosts 2018 FEICA European Adhesive & Sealant Conference and Expo
# Hot-Melt Adhesive System Solution
# Identifying the Right Adhesive Processing Equipment for the Job
# Disposable Hygiene: One Core Adhesive Does Not Fit All
# What you need to know about rollers for adhesives and coating processes
# Short Courses at 2018 ASC Convention and Expo
# Innovating with Light
# Advancing Adhesives: High-Performance Epoxy Paste for Aircraft Applications
# European Waterborne Adhesives, Active and Intelligent Packaging, Construction Chemicals
# Regulatory Review: Examining the recent U.S. Environmental Protection Agency (EPA) policy decision concerning chlorinated paraffins
# Celebrating Opportunities for Adhesives and Sealants
# Carbon Dioxide Spray Cleaning for Modern Manufacturing
# Tape Summit 2018 Discusses the Ins and Outs of PSA Tape
# Carbon Dioxide Collaboration
# Construction Tape Trends
# Coatings Trends for Plastic Parts
# Ask Dr. Dave: What advantages do I have if I choose an adhesive that has MIL-SPEC approval?
# Strategic Solutions: The Voice of the Customer
# What Will Our Legacy Be to the Adhesives & Sealants Industry?
# Market Trends: Additive Manufacturing on the Rise
# Case Study: Corrugated Converter "Sticks It" to High Costs
# At Long Last, TSCA Reform Passes
# Improving Customer Care
# Product Profile: Static Mixers
# Ask Dr. Dave: Can you help us with a crystallization problem in the part-A (epoxy side) of our two-part epoxy putty compound?

# %%
articles_collection.count()
# Out:
# /Users/ericwk/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 597
